# %% [markdown]
# # Regression Predict Student Solution
#
# © Explore Data Science Academy
#
# ---
# ### Honour Code
#
# I {**YOUR NAME, YOUR SURNAME**}, confirm - by submitting this document - that the solutions in this notebook are a result of my own work and that I abide by the [EDSA honour code](https://drive.google.com/file/d/1QDCjGZJ8-FmJE3bZdIQNwnJyQKPhHZBn/view?usp=sharing).
#
# Non-compliance with the honour code constitutes a material breach of contract.
#
# ### Predict Overview: Spain Electricity Shortfall Challenge
#
# The government of Spain is considering an expansion of it's renewable energy resource infrastructure investments. As such, they require information on the trends and patterns of the countries renewable sources and fossil fuel energy generation. Your company has been awarded the contract to:
#
# - 1. analyse the supplied data;
# - 2. identify potential errors in the data and clean the existing data set;
# - 3. determine if additional features can be added to enrich the data set;
# - 4. build a model that is capable of forecasting the three hourly demand shortfalls;
# - 5. evaluate the accuracy of the best machine learning model;
# - 6. determine what features were most important in the model’s prediction decision, and
# - 7. explain the inner working of the model to a non-technical audience.
#
# Formally the problem statement was given to you, the senior data scientist, by your manager via email reads as follow:
#
# > In this project you are tasked to model the shortfall between the energy generated by means of fossil fuels and various renewable sources - for the country of Spain. The daily shortfall, which will be referred to as the target variable, will be modelled as a function of various city-specific weather features such as `pressure`, `wind speed`, `humidity`, etc. As with all data science projects, the provided features are rarely adequate predictors of the target variable. As such, you are required to perform feature engineering to ensure that you will be able to accurately model Spain's three hourly shortfalls.
#
# On top of this, she has provided you with a starter notebook containing vague explanations of what the main outcomes are.

# %% [markdown]
# <a id="cont"></a>
#
# ## Table of Contents
#
# <a href=#one>1. Importing Packages</a>
#
# <a href=#two>2. Loading Data</a>
#
# <a href=#three>3. Exploratory Data Analysis (EDA)</a>
#
# <a href=#four>4. Data Engineering</a>
#
# <a href=#five>5. Modeling</a>
#
# <a href=#six>6. Model Performance</a>
#
# <a href=#seven>7. Model Explanations</a>

# %% [markdown]
#  <a id="one"></a>
# ## 1. Importing Packages
# <a href=#cont>Back to Table of Contents</a>
#
# ---
#
# | ⚡ Description: Importing Packages ⚡ |
# | :--------------------------- |
# | In this section you are required to import, and briefly discuss, the libraries that will be used throughout your analysis and modelling. |
#
# ---

# %%
# Libraries for data loading, data manipulation and data visulisation
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
from scipy.stats import norm
warnings.filterwarnings('ignore')

# Libraries for data preparation and model building
from sklearn.linear_model import LinearRegression

# Setting global constants to ensure notebook results are reproducible
PARAMETER_CONSTANT = 100.1

# %% [markdown]
# <a id="two"></a>
# ## 2. Loading the Data
# <a class="anchor" id="1.1"></a>
# <a href=#cont>Back to Table of Contents</a>
#
# ---
#
# | ⚡ Description: Loading the data ⚡ |
# | :--------------------------- |
# | In this section you are required to load the data from the `df_train` file into a DataFrame. |
#
# ---

# %%
df_test = pd.read_csv('df_test.csv')
df_train = pd.read_csv('df_train.csv')# load the data

# %% [markdown]
# <a id="three"></a>
# ## 3. Exploratory Data Analysis (EDA)
# <a class="anchor" id="1.1"></a>
# <a href=#cont>Back to Table of Contents</a>
#
# ---
#
# | ⚡ Description: Exploratory data analysis ⚡ |
# | :--------------------------- |
# | In this section, you are required to perform an in-depth analysis of all the variables in the DataFrame. |
#
# ---

# %%
# look at data statistics
df_train.describe().T
# Out:
#                        count          mean           std          min  \
# Unnamed: 0            8763.0   4381.000000   2529.804538     0.000000
# Madrid_wind_speed     8763.0      2.425729      1.850371     0.000000
# Bilbao_rain_1h        8763.0      0.135753      0.374901     0.000000
# Valencia_wind_speed   8763.0      2.586272      2.411190     0.000000
# Seville_humidity      8763.0     62.658793     22.621226     8.333333
# Madrid_humidity       8763.0     57.414717     24.335396     6.333333
# Bilbao_clouds_all     8763.0     43.469132     32.551044     0.000000
# Bilbao_wind_speed     8763.0      1.850356      1.695888     0.000000
# Seville_clouds_all    8763.0     13.714748     24.272482     0.000000
# Bilbao_wind_deg       8763.0    158.957511    102.056299     0.000000
# Barcelona_wind_speed  8763.0      2.870497      1.792197     0.000000
# Barcelona_wind_deg    8763.0    190.544848     89.077337     0.000000
# Madrid_clouds_all     8763.0     19.473392     28.053660     0.000000
# Seville_wind_speed    8763.0      2.425045      1.672895     0.000000
# Barcelona_rain_1h     8763.0      0.128906      0.634730     0.000000
# Seville_rain_1h       8763.0      0.039439      0.175857     0.000000
# Bilbao_snow_3h        8763.0      0.031912      0.557264     0.000000
# Barcelona_pressure    8763.0   1377.964605  14073.140990   670.666667
# Seville_rain_3h       8763.0      0.000243      0.003660     0.000000
# Madrid_rain_1h        8763.0      0.037818      0.152639     0.000000
# Barcelona_rain_3h     8763.0      0.000439      0.003994     0.000000
# Valencia_snow_3h      8763.0      0.000205      0.011866     0.000000
# Madrid_weather_id     8763.0    773.527594     77.313315   211.000000
# Barcelona_weather_id  8763.0    765.979687     88.142235   200.666667
# Bilbao_pressure       8763.0   1017.739549     10.046124   971.333333
# Seville_weather_id    8763.0    774.658818     71.940009   200.000000
# Valencia_pressure     6695.0   1012.051407      9.506214   972.666667
# Seville_temp_max      8763.0    297.479527      8.875812   272.063000
# Madrid_pressure       8763.0   1010.316920     22.198555   927.666667
# Valencia_temp_max     8763.0    291.337233      7.565692   269.888000
# Valencia_temp         8763.0    290.592152      7.162274   269.888000
# Bilbao_weather_id     8763.0    724.722362    115.846537   207.333333
# Seville_temp          8763.0    293.978903      7.920986   272.063000
# Valencia_humidity     8763.0     65.247727     19.262322    10.333333
# Valencia_temp_min     8763.0    289.867648      6.907402   269.888000
# Barcelona_temp_max    8763.0    291.157644      7.273538   272.150000
# Madrid_temp_max       8763.0    289.540309      9.752047   264.983333
# Barcelona_temp        8763.0    289.855459      6.528111   270.816667
# Bilbao_temp_min       8763.0    285.017973      6.705672   264.483333
# Bilbao_temp           8763.0    286.422929      6.818682   267.483333
# Barcelona_temp_min    8763.0    288.447422      6.102593   269.483333
# Bilbao_temp_max       8763.0    287.966027      7.105590   269.063000
# Seville_temp_min      8763.0    291.633356      8.178220   270.150000
# Madrid_temp           8763.0    288.419439      9.346796   264.983333
# Madrid_temp_min       8763.0    287.202203      9.206237   264.983333
# load_shortfall_3h     8763.0  10673.857612   5218.046404 -6618.000000
#
#                               25%           50%           75%           max
# Unnamed: 0            2190.500000   4381.000000   6571.500000  8.762000e+03
# Madrid_wind_speed        1.000000      2.000000      3.333333  1.300000e+01
# Bilbao_rain_1h           0.000000      0.000000      0.100000  3.000000e+00
# Valencia_wind_speed      1.000000      1.666667      3.666667  5.200000e+01
# Seville_humidity        44.333333     65.666667     82.000000  1.000000e+02
# Madrid_humidity         36.333333     58.000000     78.666667  1.000000e+02
# Bilbao_clouds_all       10.000000     45.000000     75.000000  1.000000e+02
# Bilbao_wind_speed        0.666667      1.000000      2.666667  1.266667e+01
# Seville_clouds_all       0.000000      0.000000     20.000000  9.733333e+01
# Bilbao_wind_deg         73.333333    147.000000    234.000000  3.593333e+02
# Barcelona_wind_speed     1.666667      2.666667      4.000000  1.266667e+01
# Barcelona_wind_deg     118.166667    200.000000    260.000000  3.600000e+02
# Madrid_clouds_all        0.000000      0.000000     33.333333  1.000000e+02
# Seville_wind_speed       1.000000      2.000000      3.333333  1.166667e+01
# Barcelona_rain_1h        0.000000      0.000000      0.000000  1.200000e+01
# Seville_rain_1h          0.000000      0.000000      0.000000  3.000000e+00
# Bilbao_snow_3h           0.000000      0.000000      0.000000  2.130000e+01
# Barcelona_pressure    1014.000000   1018.000000   1022.000000  1.001411e+06
# Seville_rain_3h          0.000000      0.000000      0.000000  9.333333e-02
# Madrid_rain_1h           0.000000      0.000000      0.000000  3.000000e+00
# Barcelona_rain_3h        0.000000      0.000000      0.000000  9.300000e-02
# Valencia_snow_3h         0.000000      0.000000      0.000000  7.916667e-01
# Madrid_weather_id      800.000000    800.000000    800.666667  8.040000e+02
# Barcelona_weather_id   800.000000    800.333333    801.000000  8.040000e+02
# Bilbao_pressure       1013.000000   1019.000000   1024.000000  1.042000e+03
# Seville_weather_id     800.000000    800.000000    800.000000  8.040000e+02
# Valencia_pressure     1010.333333   1015.000000   1018.000000  1.021667e+03
# Seville_temp_max       291.312750    297.101667    304.150000  3.204833e+02
# Madrid_pressure       1012.333333   1017.333333   1022.000000  1.038000e+03
# Valencia_temp_max      285.550167    291.037000    297.248333  3.142633e+02
# Valencia_temp          285.150000    290.176667    296.056667  3.104267e+02
# Bilbao_weather_id      700.333333    800.000000    801.666667  8.040000e+02
# Seville_temp           288.282917    293.323333    299.620333  3.149767e+02
# Valencia_humidity       51.333333     67.000000     81.333333  1.000000e+02
# Valencia_temp_min      284.783333    289.550000    294.820000  3.102720e+02
# Barcelona_temp_max     285.483333    290.150000    296.855000  3.140767e+02
# Madrid_temp_max        282.150000    288.116177    296.816667  3.144833e+02
# Barcelona_temp         284.973443    289.416667    294.909000  3.073167e+02
# Bilbao_temp_min        280.085167    284.816667    289.816667  3.098167e+02
# Bilbao_temp            281.374167    286.158333    291.034167  3.107100e+02
# Barcelona_temp_min     284.150000    288.150000    292.966667  3.048167e+02
# Bilbao_temp_max        282.836776    287.630000    292.483333  3.179667e+02
# Seville_temp_min       285.816667    290.816667    297.150000  3.148167e+02
# Madrid_temp            281.404281    287.053333    295.154667  3.131333e+02
# Madrid_temp_min        280.299167    286.083333    293.884500  3.103833e+02
# load_shortfall_3h     7390.333333  11114.666667  14498.166667  3.190400e+04

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8763 entries, 0 to 8762
# Data columns (total 49 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Unnamed: 0            8763 non-null   int64
#  1   time                  8763 non-null   object
#  2   Madrid_wind_speed     8763 non-null   float64
#  3   Valencia_wind_deg     8763 non-null   object
#  4   Bilbao_rain_1h        8763 non-null   float64
#  5   Valencia_wind_speed   8763 non-null   float64
#  6   Seville_humidity      8763 non-null   float64
#  7   Madrid_humidity       8763 non-null   float64
#  8   Bilbao_clouds_all     8763 non-null   float64
#  9   Bilbao_wind_speed     8763 non-null   float64
#  10  Seville_clouds_all    8763 non-null   float64
#  11  Bilbao_wind_deg       8763 non-null   float64
#  12  Barcelona_wind_speed  8763 non-null   float64
#  13  Barcelona_wind_deg    8763 non-null   float64
#  14  Madrid_clouds_all     8763 non-null   float64
#  15  Seville_wind_speed    8763 non-null   float64
#  16  Barcelona_rain_1h     8763 non-null   float64
#  17  Seville_pressure      8763 non-null   object
#  18  Seville_rain_1h       8763 non-null   float64
#  19  Bilbao_snow_3h        8763 non-null   float64
#  20  Barcelona_pressure    8763 non-null   float64
#  21  Seville_rain_3h       8763 non-null   float64
#  22  Madrid_rain_1h        8763 non-null   float64
#  23  Barcelona_rain_3h     8763 non-null   float64
#  24  Valencia_snow_3h      8763 non-null   float64
#  25  Madrid_weather_id     8763 non-null   float64
#  26  Barcelona_weather_id  8763 non-null   float64
#  27  Bilbao_pressure       8763 non-null   float64
#  28  Seville_weather_id    8763 non-null   float64
#  29  Valencia_pressure     6695 non-null   float64
#  30  Seville_temp_max      8763 non-null   float64
#  31  Madrid_pressure       8763 non-null   float64
#  32  Valencia_temp_max     8763 non-null   float64
#  33  Valencia_temp         8763 non-null   float64
#  34  Bilbao_weather_id     8763 non-null   float64
#  35  Seville_temp          8763 non-null   float64
#  36  Valencia_humidity     8763 non-null   float64
#  37  Valencia_temp_min     8763 non-null   float64
#  38  Barcelona_temp_max    8763 non-null   float64
#  39  Madrid_temp_max       8763 non-null   float64
#  40  Barcelona_temp        8763 non-null   float64
#  41  Bilbao_temp_min       8763 non-null   float64
#  42  Bilbao_temp           8763 non-null   float64
#  43  Barcelona_temp_min    8763 non-null   float64
#  44  Bilbao_temp_max       8763 non-null   float64
#  45  Seville_temp_min      8763 non-null   float64
#  46  Madrid_temp           8763 non-null   float64
#  47  Madrid_temp_min       8763 non-null   float64
#  48  load_shortfall_3h     8763 non-null   float64
# dtypes: float64(45), int64(1), object(3)
# memory usage: 3.3+ MB

# %%
df_train.head()
# Out:
#    Unnamed: 0                 time  Madrid_wind_speed Valencia_wind_deg  \
# 0           0  2015-01-01 03:00:00           0.666667           level_5
# 1           1  2015-01-01 06:00:00           0.333333          level_10
# 2           2  2015-01-01 09:00:00           1.000000           level_9
# 3           3  2015-01-01 12:00:00           1.000000           level_8
# 4           4  2015-01-01 15:00:00           1.000000           level_7
#
#    Bilbao_rain_1h  Valencia_wind_speed  Seville_humidity  Madrid_humidity  \
# 0             0.0             0.666667         74.333333        64.000000
# 1             0.0             1.666667         78.333333        64.666667
# 2             0.0             1.000000         71.333333        64.333333
# 3             0.0             1.000000         65.333333        56.333333
# 4             0.0             1.000000         59.000000        57.000000
#
#    Bilbao_clouds_all  Bilbao_wind_speed  ...  Madrid_temp_max  Barcelona_temp  \
# 0                0.0           1.000000  ...       265.938000      281.013000
# 1                0.0           1.000000  ...       266.386667      280.561667
# 2                0.0           1.000000  ...       272.708667      281.583667
# 3                0.0           1.000000  ...       281.895219      283.434104
# 4                2.0           0.333333  ...       280.678437      284.213167
#
#    Bilbao_temp_min  Bilbao_temp  Barcelona_temp_min  Bilbao_temp_max  \
# 0       269.338615   269.338615          281.013000       269.338615
# 1       270.376000   270.376000          280.561667       270.376000
# 2       275.027229   275.027229          281.583667       275.027229
# 3       281.135063   281.135063          283.434104       281.135063
# 4       282.252063   282.252063          284.213167       282.252063
#
#    Seville_temp_min Madrid_temp  Madrid_temp_min  load_shortfall_3h
# 0        274.254667  265.938000       265.938000        6715.666667
# 1        274.945000  266.386667       266.386667        4171.666667
# 2        278.792000  272.708667       272.708667        4274.666667
# 3        285.394000  281.895219       281.895219        5075.666667
# 4        285.513719  280.678437       280.678437        6620.666667
#
# [5 rows x 49 columns]

# %%
print('train:', df_train.shape)
# Out:
# train: (8763, 49)

# %%
sns.distplot(df_train['load_shortfall_3h'], fit=norm)
plt.title('Histogram of load_shortfall_3h')
plt.xlabel('Load shortfall (3hrs)')
# Out:
# Text(0.5, 0, 'Load shortfall (3hrs)')

# %%
print("Skewness: {:.6f}".format(df_train['load_shortfall_3h'].skew()))
print("Kurtosis: {:.6f}".format(df_train['load_shortfall_3h'].kurt()))
# Out:
# Skewness: -0.384847
# Kurtosis: -0.118999

# %%
# plot relevant feature interactions
wind_speed = df_train[['Madrid_wind_speed', 'Valencia_wind_speed', 'Bilbao_wind_speed', 'Barcelona_wind_speed', 
                      'Seville_wind_speed']]
fig = plt.figure(figsize=(20,12))
axs = fig.subplots(2, 3)
for ax, column in zip(axs.ravel(), wind_speed.columns.tolist()):
    ax.scatter(wind_speed[column], df_train['load_shortfall_3h'])
    ax.title.set_text('{} Vs Load shortfall (3Hrs)'.format(column))
    ax.set_xlabel('{}'.format(column))
plt.show()

# %%
wind_deg_columns = [col for col in df_train.columns if col.endswith('_wind_deg')]
wind_strength = df_train[wind_deg_columns]

fig = plt.figure(figsize=(20,12))
axs = fig.subplots(2,2)
for ax, column in zip(axs.ravel(), wind_deg_columns):
    ax.scatter(df_train[column],df_train['load_shortfall_3h'])
    ax.title.set_text('{} Vs Load shortfall (3Hrs)'.format(column))
    ax.set_xlabel('{}'.format(column))
plt.show()

# %%
rain_1hr_columns = [col for col in df_train.columns if col.endswith('_rain_1h')]
one_hr_rain = df_train[rain_1hr_columns]

fig = plt.figure(figsize=(20,12))
axs = fig.subplots(2,2)
for ax, column in zip(axs.ravel(), rain_1hr_columns):
    ax.scatter(df_train[column],df_train['load_shortfall_3h'])
    ax.title.set_text('{} Vs Load shortfall (3Hrs)'.format(column))
    ax.set_xlabel('{}'.format(column))
plt.show()

# %%
rain_3hr_columns = [col for col in df_train.columns if col.endswith('_rain_3h')]
three_hr_rain = df_train[rain_3hr_columns]

fig = plt.figure(figsize=(20,9))
axs = fig.subplots(1,2)
for ax, column in zip(axs.ravel(), rain_3hr_columns):
    ax.scatter(df_train[column],df_train['load_shortfall_3h'])
    ax.title.set_text('{} Vs Load shortfall (3Hrs)'.format(column))
    ax.set_xlabel('{}'.format(column))
plt.show()

# %%
humidity_columns = [col for col in df_train.columns if col.endswith('_humidity')]
humidity = df_train[humidity_columns]

fig = plt.figure(figsize=(20,12))
axs = fig.subplots(2,2)
for ax, column in zip(axs.ravel(), humidity_columns):
    ax.scatter(df_train[column],df_train['load_shortfall_3h'])
    ax.title.set_text('{} Vs Load shortfall (3Hrs)'.format(column))
    ax.set_xlabel('{}'.format(column))
plt.show()

# %%
clouds_all_columns = [col for col in df_train.columns if col.endswith('_clouds_all')]
clouds_all = df_train[clouds_all_columns]

fig = plt.figure(figsize=(20,12))
axs = fig.subplots(2,2)
for ax, column in zip(axs.ravel(), clouds_all_columns):
    ax.scatter(df_train[column],df_train['load_shortfall_3h'])
    ax.title.set_text('{} Vs Load shortfall (3Hrs)'.format(column))
    ax.set_xlabel('{}'.format(column))
plt.show()

# %%
pressure_columns = [col for col in df_train.columns if col.endswith('_pressure')]
pressure = df_train[pressure_columns]

fig = plt.figure(figsize=(20,12))
axs = fig.subplots(3,2)
for ax, column in zip(axs.ravel(), pressure_columns):
    ax.scatter(df_train[column],df_train['load_shortfall_3h'])
    ax.title.set_text('{} Vs Load shortfall (3Hrs)'.format(column))
    ax.set_xlabel('{}'.format(column))
fig.tight_layout(pad=3.0)
plt.show()

# %%
snow_3h_columns = [col for col in df_train.columns if col.endswith('_snow_3h')]
snow_3h = df_train[snow_3h_columns]

fig = plt.figure(figsize=(20,8))
axs = fig.subplots(1,2)
for ax, column in zip(axs.ravel(), snow_3h_columns):
    ax.scatter(df_train[column],df_train['load_shortfall_3h'])
    ax.title.set_text('{} Vs Load shortfall (3Hrs)'.format(column))
    ax.set_xlabel('{}'.format(column))
plt.show()

# %%
weather_id_columns = [col for col in df_train.columns if col.endswith('_weather_id')]
weather_id = df_train[weather_id_columns]

fig = plt.figure(figsize=(20,12))
axs = fig.subplots(2,2)
for ax, column in zip(axs.ravel(), weather_id_columns):
    ax.scatter(df_train[column],df_train['load_shortfall_3h'])
    ax.title.set_text('{} Vs Load shortfall (3Hrs)'.format(column))
    ax.set_xlabel('{}'.format(column))
plt.show()

# %%
temp_max_columns = [col for col in df_train.columns if col.endswith('_temp_max')]
temp_max = df_train[temp_max_columns]

fig = plt.figure(figsize=(20,12))
axs = fig.subplots(3,2)
for ax, column in zip(axs.ravel(), temp_max_columns):
    ax.scatter(df_train[column],df_train['load_shortfall_3h'])
    ax.title.set_text('{} Vs Load shortfall (3Hrs)'.format(column))
    ax.set_xlabel('{}'.format(column))
fig.tight_layout(pad=3.0)
plt.show()

# %%
temp_min_columns = [col for col in df_train.columns if col.endswith('_temp_min')]
temp_min = df_train[temp_min_columns]

fig = plt.figure(figsize=(20,12))
axs = fig.subplots(3,2)
for ax, column in zip(axs.ravel(), temp_min_columns):
    ax.scatter(df_train[column],df_train['load_shortfall_3h'])
    ax.title.set_text('{} Vs Load shortfall (3Hrs)'.format(column))
    ax.set_xlabel('{}'.format(column))
fig.tight_layout(pad=3.0)
plt.show()

# %%
temp_columns = [col for col in df_train.columns if col.endswith('_temp')]
temp = df_train[temp_columns]

fig = plt.figure(figsize=(20,12))
axs = fig.subplots(3,2)
for ax, column in zip(axs.ravel(), temp_columns):
    ax.scatter(df_train[column],df_train['load_shortfall_3h'])
    ax.title.set_text('{} Vs Load shortfall (3Hrs)'.format(column))
    ax.set_xlabel('{}'.format(column))
fig.tight_layout(pad=3.0)
plt.show()

# %%
# evaluate correlation
correlation = df_train.corr()
fig = plt.figure(figsize=(20,12)).add_subplot(111)
sns.set_theme()
sns.heatmap(correlation, square=True)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# - It appears that all features relating to temperature `('Seville_temp_max', 'Valencia_temp_max', 'Valencia_temp', 'Seville_temp', 'Valencia_temp_min', 'Barcelona_temp_max', 'Madrid_temp_max', 'Barcelona_temp', 'Bilbao_temp_min', 'Bilbao_temp', 'Barcelona_temp_min', 'Bilbao_temp_max', 'Seville_temp_min', 'Madrid_temp', 'Madrid_temp_min')` are strongly correlated which can introduce multicolinearity.
# - `Seville_humidity` and `Madrid_humidity` are also strongly correlated with these temperature columns
# The following columns are as well strongly correlated
# - `Madrid_rain_1h` and `Madrid_weather_id`
# - `Seville_rain_1h` and `Seville weather_id`
# - `Barcelona_rain_ih` and `Barcelona_weather`
# - `Madrid_clouds_all` and `Madrid_weather_id`
# - `Seville_clouds_all` and `Seville_weather_id`
# - `Bilbao_clouds_all` and `Bilbao_weather_id`
# - `Bilbao_rain_1h` and `Bilbao_weather_id`
#
# A correlation matrix will confirm this

# %%
# have a look at feature distributions
wind_speed = df_train[['Madrid_wind_speed', 'Valencia_wind_speed', 'Bilbao_wind_speed', 'Barcelona_wind_speed', 'Seville_wind_speed']]

fig, axs = plt.subplots(2, 3, figsize=(20, 12))
axs = axs.ravel()

for i, column in enumerate(wind_speed.columns.tolist()):
    sns.distplot(df_train[column], ax=axs[i], fit=norm)
    axs[i].set_title('{} Distribution'.format(column))
    axs[i].set_xlabel('{}'.format(column))

plt.show()

# %%
wind_deg_columns = [col for col in df_train.columns if col.endswith('_wind_deg')]
wind_strength = df_train[wind_deg_columns]

fig, axs = plt.subplots(2, 2, figsize=(20, 12))
axs = axs.ravel()

for i, column in enumerate(wind_deg_columns):
    if df_train[column].dtype == 'object':
        axs[i].hist(df_train[column], density='True', alpha=0.5)
    else:
        sns.distplot(df_train[column], ax=axs[i], fit=norm)
    axs[i].set_title('{} Distribution'.format(column))
    axs[i].set_xlabel('{}'.format(column))

plt.show()

# %%
rain_1h_columns = [col for col in df_train.columns if col.endswith('_rain_1h')]
one_hr_rain = df_train[rain_1hr_columns]

fig, axs = plt.subplots(2, 2, figsize=(20, 12))
axs = axs.ravel()

for i, column in enumerate(rain_1h_columns):
    sns.distplot(df_train[column], ax=axs[i], fit=norm)
    axs[i].set_title('{} Distribution'.format(column))
    axs[i].set_xlabel('{}'.format(column))

plt.show()

# %%
rain_3h_columns = [col for col in df_train.columns if col.endswith('_rain_3h')]
three_hr_rain = df_train[rain_3hr_columns]

fig, axs = plt.subplots(1, 2, figsize=(20, 7))
axs = axs.ravel()

for i, column in enumerate(rain_3h_columns):
    sns.distplot(df_train[column], ax=axs[i], fit=norm)
    axs[i].set_title('{} Distribution'.format(column))
    axs[i].set_xlabel('{}'.format(column))

plt.show()

# %%
humidity_columns = [col for col in df_train.columns if col.endswith('_humidity')]

fig, axs = plt.subplots(2, 2, figsize=(20, 12))
axs = axs.ravel()

for i, column in enumerate(humidity_columns):
    sns.distplot(df_train[column], ax=axs[i], fit=norm)
    axs[i].set_title('{} Distribution'.format(column))
    axs[i].set_xlabel('{}'.format(column))

plt.show()

# %%
clouds_all_columns = [col for col in df_train.columns if col.endswith('_clouds_all')]

fig, axs = plt.subplots(2, 2, figsize=(20, 12))
axs = axs.ravel()

for i, column in enumerate(clouds_all_columns):
    sns.distplot(df_train[column], ax=axs[i], fit=norm)
    axs[i].set_title('{} Distribution'.format(column))
    axs[i].set_xlabel('{}'.format(column))

plt.show()

# %%
pressure_columns = [col for col in df_train.columns if col.endswith('_pressure')]

fig, axs = plt.subplots(3, 2, figsize=(20, 18))
axs = axs.ravel()

for i, column in enumerate(pressure_columns):
    if df_train[column].dtype == 'object':
        axs[i].hist(df_train[column], density='True', alpha=0.5)
    else:
        sns.distplot(df_train[column], ax=axs[i], fit=norm)
    axs[i].set_title('{} Distribution'.format(column))
    axs[i].set_xlabel('{}'.format(column))
plt.show()

# %%
snow_3h_columns = [col for col in df_train.columns if col.endswith('_snow_3h')]

fig, axs = plt.subplots(1, 2, figsize=(20, 7))
axs = axs.ravel()

for i, column in enumerate(snow_3h_columns):
    sns.distplot(df_train[column], ax=axs[i], fit=norm)
    axs[i].set_title('{} Distribution'.format(column))
    axs[i].set_xlabel('{}'.format(column))

plt.show()

# %%
weather_id_columns = [col for col in df_train.columns if col.endswith('_weather_id')]

fig, axs = plt.subplots(2, 2, figsize=(20, 12))
axs = axs.ravel()

for i, column in enumerate(weather_id_columns):
    sns.distplot(df_train[column], ax=axs[i], fit=norm)
    axs[i].set_title('{} Distribution'.format(column))
    axs[i].set_xlabel('{}'.format(column))

plt.show()

# %%
temp_max_columns = [col for col in df_train.columns if col.endswith('_temp_max')]

fig, axs = plt.subplots(3, 2, figsize=(20, 18))
axs = axs.ravel()

for i, column in enumerate(temp_max_columns):
    sns.distplot(df_train[column], ax=axs[i], fit=norm)
    axs[i].set_title('{} Distribution'.format(column))
    axs[i].set_xlabel('{}'.format(column))

plt.show()

# %%
temp_min_columns = [col for col in df_train.columns if col.endswith('_temp_min')]

fig, axs = plt.subplots(3, 2, figsize=(20, 18))
axs = axs.ravel()

for i, column in enumerate(temp_min_columns):
    sns.distplot(df_train[column], ax=axs[i], fit=norm)
    axs[i].set_title('{} Distribution'.format(column))
    axs[i].set_xlabel('{}'.format(column))

plt.show()

# %%
temp_columns = [col for col in df_train.columns if col.endswith('_temp')]

fig, axs = plt.subplots(3, 2, figsize=(20, 18))
axs = axs.ravel()

for i, column in enumerate(temp_columns):
    sns.distplot(df_train[column], ax=axs[i], fit=norm)
    axs[i].set_title('{} Distribution'.format(column))
    axs[i].set_xlabel('{}'.format(column))

plt.show()

# %% [markdown]
# <a id="four"></a>
# ## 4. Data Engineering
# <a class="anchor" id="1.1"></a>
# <a href=#cont>Back to Table of Contents</a>
#
# ---
#
# | ⚡ Description: Data engineering ⚡ |
# | :--------------------------- |
# | In this section you are required to: clean the dataset, and possibly create new features - as identified in the EDA phase. |
#
# ---

# %%
# remove missing values/ features
df = pd.concat([df_train, df_test])#combining train and test set so clean can be don on both at once

# %%
df.isnull().sum() #checking for columns with null values
# Out:
# Unnamed: 0                 0
# time                       0
# Madrid_wind_speed          0
# Valencia_wind_deg          0
# Bilbao_rain_1h             0
# Valencia_wind_speed        0
# Seville_humidity           0
# Madrid_humidity            0
# Bilbao_clouds_all          0
# Bilbao_wind_speed          0
# Seville_clouds_all         0
# Bilbao_wind_deg            0
# Barcelona_wind_speed       0
# Barcelona_wind_deg         0
# Madrid_clouds_all          0
# Seville_wind_speed         0
# Barcelona_rain_1h          0
# Seville_pressure           0
# Seville_rain_1h            0
# Bilbao_snow_3h             0
# Barcelona_pressure         0
# Seville_rain_3h            0
# Madrid_rain_1h             0
# Barcelona_rain_3h          0
# Valencia_snow_3h           0
# Madrid_weather_id          0
# Barcelona_weather_id       0
# Bilbao_pressure            0
# Seville_weather_id         0
# Valencia_pressure       2522
# Seville_temp_max           0
# Madrid_pressure            0
# Valencia_temp_max          0
# Valencia_temp              0
# Bilbao_weather_id          0
# Seville_temp               0
# Valencia_humidity          0
# Valencia_temp_min          0
# Barcelona_temp_max         0
# Madrid_temp_max            0
# Barcelona_temp             0
# Bilbao_temp_min            0
# Bilbao_temp                0
# Barcelona_temp_min         0
# Bilbao_temp_max            0
# Seville_temp_min           0
# Madrid_temp                0
# Madrid_temp_min            0
# load_shortfall_3h       2920
# dtype: int64

# %%
'''
    as seen above the column "Valencia_pressure" has 
    2522 missing values and is to be removed
'''
df_clean = df #creating a new separate dataset to make changes on 
df_clean = df_clean.drop('Valencia_pressure', axis=1)

# %%
df_clean.isnull().sum()#confirming removal of column
# Out:
# Unnamed: 0                 0
# time                       0
# Madrid_wind_speed          0
# Valencia_wind_deg          0
# Bilbao_rain_1h             0
# Valencia_wind_speed        0
# Seville_humidity           0
# Madrid_humidity            0
# Bilbao_clouds_all          0
# Bilbao_wind_speed          0
# Seville_clouds_all         0
# Bilbao_wind_deg            0
# Barcelona_wind_speed       0
# Barcelona_wind_deg         0
# Madrid_clouds_all          0
# Seville_wind_speed         0
# Barcelona_rain_1h          0
# Seville_pressure           0
# Seville_rain_1h            0
# Bilbao_snow_3h             0
# Barcelona_pressure         0
# Seville_rain_3h            0
# Madrid_rain_1h             0
# Barcelona_rain_3h          0
# Valencia_snow_3h           0
# Madrid_weather_id          0
# Barcelona_weather_id       0
# Bilbao_pressure            0
# Seville_weather_id         0
# Seville_temp_max           0
# Madrid_pressure            0
# Valencia_temp_max          0
# Valencia_temp              0
# Bilbao_weather_id          0
# Seville_temp               0
# Valencia_humidity          0
# Valencia_temp_min          0
# Barcelona_temp_max         0
# Madrid_temp_max            0
# Barcelona_temp             0
# Bilbao_temp_min            0
# Bilbao_temp                0
# Barcelona_temp_min         0
# Bilbao_temp_max            0
# Seville_temp_min           0
# Madrid_temp                0
# Madrid_temp_min            0
# load_shortfall_3h       2920
# dtype: int64

# %%
# create new features
df_clean.dtypes #checking datatypes of columns
# Out:
# Unnamed: 0                int64
# time                     object
# Madrid_wind_speed       float64
# Valencia_wind_deg        object
# Bilbao_rain_1h          float64
# Valencia_wind_speed     float64
# Seville_humidity        float64
# Madrid_humidity         float64
# Bilbao_clouds_all       float64
# Bilbao_wind_speed       float64
# Seville_clouds_all      float64
# Bilbao_wind_deg         float64
# Barcelona_wind_speed    float64
# Barcelona_wind_deg      float64
# Madrid_clouds_all       float64
# Seville_wind_speed      float64
# Barcelona_rain_1h       float64
# Seville_pressure         object
# Seville_rain_1h         float64
# Bilbao_snow_3h          float64
# Barcelona_pressure      float64
# Seville_rain_3h         float64
# Madrid_rain_1h          float64
# Barcelona_rain_3h       float64
# Valencia_snow_3h        float64
# Madrid_weather_id       float64
# Barcelona_weather_id    float64
# Bilbao_pressure         float64
# Seville_weather_id      float64
# Seville_temp_max        float64
# Madrid_pressure         float64
# Valencia_temp_max       float64
# Valencia_temp           float64
# Bilbao_weather_id       float64
# Seville_temp            float64
# Valencia_humidity       float64
# Valencia_temp_min       float64
# Barcelona_temp_max      float64
# Madrid_temp_max         float64
# Barcelona_temp          float64
# Bilbao_temp_min         float64
# Bilbao_temp             float64
# Barcelona_temp_min      float64
# Bilbao_temp_max         float64
# Seville_temp_min        float64
# Madrid_temp             float64
# Madrid_temp_min         float64
# load_shortfall_3h       float64
# dtype: object

# %%
'''
    "Time" seems to be a potential predictor but is not of the right datatype
    fit for the regression analysis. 
    Task is to convert it to datetime object and create new features containing
    day, month and year in numeric form
'''
    
df_clean['time'] = pd.to_datetime(df_clean['time'])#converting to datetime object

# %%
df_clean.dtypes
# Out:
# Unnamed: 0                       int64
# time                    datetime64[ns]
# Madrid_wind_speed              float64
# Valencia_wind_deg               object
# Bilbao_rain_1h                 float64
# Valencia_wind_speed            float64
# Seville_humidity               float64
# Madrid_humidity                float64
# Bilbao_clouds_all              float64
# Bilbao_wind_speed              float64
# Seville_clouds_all             float64
# Bilbao_wind_deg                float64
# Barcelona_wind_speed           float64
# Barcelona_wind_deg             float64
# Madrid_clouds_all              float64
# Seville_wind_speed             float64
# Barcelona_rain_1h              float64
# Seville_pressure                object
# Seville_rain_1h                float64
# Bilbao_snow_3h                 float64
# Barcelona_pressure             float64
# Seville_rain_3h                float64
# Madrid_rain_1h                 float64
# Barcelona_rain_3h              float64
# Valencia_snow_3h               float64
# Madrid_weather_id              float64
# Barcelona_weather_id           float64
# Bilbao_pressure                float64
# Seville_weather_id             float64
# Seville_temp_max               float64
# Madrid_pressure                float64
# Valencia_temp_max              float64
# Valencia_temp                  float64
# Bilbao_weather_id              float64
# Seville_temp                   float64
# Valencia_humidity              float64
# Valencia_temp_min              float64
# Barcelona_temp_max             float64
# Madrid_temp_max                float64
# Barcelona_temp                 float64
# Bilbao_temp_min                float64
# Bilbao_temp                    float64
# Barcelona_temp_min             float64
# Bilbao_temp_max                float64
# Seville_temp_min               float64
# Madrid_temp                    float64
# Madrid_temp_min                float64
# load_shortfall_3h              float64
# dtype: object

# %%
df_clean['time']
# Out:
# 0      2015-01-01 03:00:00
# 1      2015-01-01 06:00:00
# 2      2015-01-01 09:00:00
# 3      2015-01-01 12:00:00
# 4      2015-01-01 15:00:00
#                ...
# 2915   2018-12-31 09:00:00
# 2916   2018-12-31 12:00:00
# 2917   2018-12-31 15:00:00
# 2918   2018-12-31 18:00:00
# 2919   2018-12-31 21:00:00
# Name: time, Length: 11683, dtype: datetime64[ns]

# %%
df_clean['year'] = df_clean['time'].dt.year.astype(int)#creating year column
df_clean['month'] = df_clean['time'].dt.month.astype(int)#creating month column
df_clean['day'] = df_clean['time'].dt.day.astype(int)#creating day column
df_clean['hour'] = df_clean['time'].dt.hour.astype(int)#creating hour column

df_clean.head()
# Out:
#    Unnamed: 0                time  Madrid_wind_speed Valencia_wind_deg  \
# 0           0 2015-01-01 03:00:00           0.666667           level_5
# 1           1 2015-01-01 06:00:00           0.333333          level_10
# 2           2 2015-01-01 09:00:00           1.000000           level_9
# 3           3 2015-01-01 12:00:00           1.000000           level_8
# 4           4 2015-01-01 15:00:00           1.000000           level_7
#
#    Bilbao_rain_1h  Valencia_wind_speed  Seville_humidity  Madrid_humidity  \
# 0             0.0             0.666667         74.333333        64.000000
# 1             0.0             1.666667         78.333333        64.666667
# 2             0.0             1.000000         71.333333        64.333333
# 3             0.0             1.000000         65.333333        56.333333
# 4             0.0             1.000000         59.000000        57.000000
#
#    Bilbao_clouds_all  Bilbao_wind_speed  ...  Barcelona_temp_min  \
# 0                0.0           1.000000  ...          281.013000
# 1                0.0           1.000000  ...          280.561667
# 2                0.0           1.000000  ...          281.583667
# 3                0.0           1.000000  ...          283.434104
# 4                2.0           0.333333  ...          284.213167
#
#    Bilbao_temp_max  Seville_temp_min  Madrid_temp  Madrid_temp_min  \
# 0       269.338615        274.254667   265.938000       265.938000
# 1       270.376000        274.945000   266.386667       266.386667
# 2       275.027229        278.792000   272.708667       272.708667
# 3       281.135063        285.394000   281.895219       281.895219
# 4       282.252063        285.513719   280.678437       280.678437
#
#    load_shortfall_3h  year month  day  hour
# 0        6715.666667  2015     1    1     3
# 1        4171.666667  2015     1    1     6
# 2        4274.666667  2015     1    1     9
# 3        5075.666667  2015     1    1    12
# 4        6620.666667  2015     1    1    15
#
# [5 rows x 52 columns]

# %%
# engineer existing features
'''
    "Seville_pressure" and "Valencia_wind_deg" exist as objects which should be changed to numeric values 
     to allow for regression analysis
'''

df_clean['Seville_pressure']
# Out:
# 0       sp25
# 1       sp25
# 2       sp25
# 3       sp25
# 4       sp25
#         ...
# 2915    sp24
# 2916    sp24
# 2917    sp23
# 2918    sp23
# 2919    sp23
# Name: Seville_pressure, Length: 11683, dtype: object

# %%
df_clean['Seville_pressure'].value_counts()#checking count of all unique values
# Out:
# sp10    673
# sp13    668
# sp8     629
# sp6     619
# sp4     555
# sp5     537
# sp12    523
# sp1     503
# sp21    495
# sp22    493
# sp3     477
# sp16    476
# sp17    473
# sp18    472
# sp2     467
# sp24    464
# sp19    442
# sp25    441
# sp15    426
# sp20    425
# sp23    424
# sp14    318
# sp9     259
# sp7     235
# sp11    189
# Name: Seville_pressure, dtype: int64

# %%
'''
    There are 25 unique values in the "Seville_pressure" column. Transforming this column to dummies
    make the dataframe too cumbersome. Since there are figures which sort of rank the pressures
    from lowest to highest, the best option is to extract the these numbers
'''

df_clean['Seville_pressure'] = df_clean['Seville_pressure'].str.extract('(\d+)', expand=False)

# %%
df_clean['Seville_pressure'].value_counts() #confirming
# Out:
# 10    673
# 13    668
# 8     629
# 6     619
# 4     555
# 5     537
# 12    523
# 1     503
# 21    495
# 22    493
# 3     477
# 16    476
# 17    473
# 18    472
# 2     467
# 24    464
# 19    442
# 25    441
# 15    426
# 20    425
# 23    424
# 14    318
# 9     259
# 7     235
# 11    189
# Name: Seville_pressure, dtype: int64

# %%
df_clean['Valencia_wind_deg'].value_counts() #checking count of all unique values
# Out:
# level_8     1212
# level_1     1212
# level_7     1201
# level_6     1184
# level_4     1177
# level_5     1175
# level_10    1167
# level_3     1167
# level_2     1126
# level_9     1062
# Name: Valencia_wind_deg, dtype: int64

# %%
'''
    Similar to "Seville_pressure", the best option here too is to extract the numbers
'''

df_clean['Valencia_wind_deg'] = df_clean['Valencia_wind_deg'].str.extract('(\d+)', expand=False)
df_clean['Valencia_wind_deg'].value_counts()
# Out:
# 8     1212
# 1     1212
# 7     1201
# 6     1184
# 4     1177
# 5     1175
# 10    1167
# 3     1167
# 2     1126
# 9     1062
# Name: Valencia_wind_deg, dtype: int64

# %%
df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 11683 entries, 0 to 2919
# Data columns (total 52 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Unnamed: 0            11683 non-null  int64
#  1   time                  11683 non-null  datetime64[ns]
#  2   Madrid_wind_speed     11683 non-null  float64
#  3   Valencia_wind_deg     11683 non-null  object
#  4   Bilbao_rain_1h        11683 non-null  float64
#  5   Valencia_wind_speed   11683 non-null  float64
#  6   Seville_humidity      11683 non-null  float64
#  7   Madrid_humidity       11683 non-null  float64
#  8   Bilbao_clouds_all     11683 non-null  float64
#  9   Bilbao_wind_speed     11683 non-null  float64
#  10  Seville_clouds_all    11683 non-null  float64
#  11  Bilbao_wind_deg       11683 non-null  float64
#  12  Barcelona_wind_speed  11683 non-null  float64
#  13  Barcelona_wind_deg    11683 non-null  float64
#  14  Madrid_clouds_all     11683 non-null  float64
#  15  Seville_wind_speed    11683 non-null  float64
#  16  Barcelona_rain_1h     11683 non-null  float64
#  17  Seville_pressure      11683 non-null  object
#  18  Seville_rain_1h       11683 non-null  float64
#  19  Bilbao_snow_3h        11683 non-null  float64
#  20  Barcelona_pressure    11683 non-null  float64
#  21  Seville_rain_3h       11683 non-null  float64
#  22  Madrid_rain_1h        11683 non-null  float64
#  23  Barcelona_rain_3h     11683 non-null  float64
#  24  Valencia_snow_3h      11683 non-null  float64
#  25  Madrid_weather_id     11683 non-null  float64
#  26  Barcelona_weather_id  11683 non-null  float64
#  27  Bilbao_pressure       11683 non-null  float64
#  28  Seville_weather_id    11683 non-null  float64
#  29  Seville_temp_max      11683 non-null  float64
#  30  Madrid_pressure       11683 non-null  float64
#  31  Valencia_temp_max     11683 non-null  float64
#  32  Valencia_temp         11683 non-null  float64
#  33  Bilbao_weather_id     11683 non-null  float64
#  34  Seville_temp          11683 non-null  float64
#  35  Valencia_humidity     11683 non-null  float64
#  36  Valencia_temp_min     11683 non-null  float64
#  37  Barcelona_temp_max    11683 non-null  float64
#  38  Madrid_temp_max       11683 non-null  float64
#  39  Barcelona_temp        11683 non-null  float64
#  40  Bilbao_temp_min       11683 non-null  float64
#  41  Bilbao_temp           11683 non-null  float64
#  42  Barcelona_temp_min    11683 non-null  float64
#  43  Bilbao_temp_max       11683 non-null  float64
#  44  Seville_temp_min      11683 non-null  float64
#  45  Madrid_temp           11683 non-null  float64
#  46  Madrid_temp_min       11683 non-null  float64
#  47  load_shortfall_3h     8763 non-null   float64
#  48  year                  11683 non-null  int32
#  49  month                 11683 non-null  int32
#  50  day                   11683 non-null  int32
#  51  hour                  11683 non-null  int32
# dtypes: datetime64[ns](1), float64(44), int32(4), int64(1), object(2)
# memory usage: 4.5+ MB

# %%
'''
    "Seville_pressure" and "Valencia_wind_deg" are still objects
'''
#tranforming to integers
df_clean['Seville_pressure'] = df_clean['Seville_pressure'].astype(int)
df_clean['Valencia_wind_deg'] = df_clean['Valencia_wind_deg'].astype(int)
df_clean.dtypes
# Out:
# Unnamed: 0                       int64
# time                    datetime64[ns]
# Madrid_wind_speed              float64
# Valencia_wind_deg                int32
# Bilbao_rain_1h                 float64
# Valencia_wind_speed            float64
# Seville_humidity               float64
# Madrid_humidity                float64
# Bilbao_clouds_all              float64
# Bilbao_wind_speed              float64
# Seville_clouds_all             float64
# Bilbao_wind_deg                float64
# Barcelona_wind_speed           float64
# Barcelona_wind_deg             float64
# Madrid_clouds_all              float64
# Seville_wind_speed             float64
# Barcelona_rain_1h              float64
# Seville_pressure                 int32
# Seville_rain_1h                float64
# Bilbao_snow_3h                 float64
# Barcelona_pressure             float64
# Seville_rain_3h                float64
# Madrid_rain_1h                 float64
# Barcelona_rain_3h              float64
# Valencia_snow_3h               float64
# Madrid_weather_id              float64
# Barcelona_weather_id           float64
# Bilbao_pressure                float64
# Seville_weather_id             float64
# Seville_temp_max               float64
# Madrid_pressure                float64
# Valencia_temp_max              float64
# Valencia_temp                  float64
# Bilbao_weather_id              float64
# Seville_temp                   float64
# Valencia_humidity              float64
# Valencia_temp_min              float64
# Barcelona_temp_max             float64
# Madrid_temp_max                float64
# Barcelona_temp                 float64
# Bilbao_temp_min                float64
# Bilbao_temp                    float64
# Barcelona_temp_min             float64
# Bilbao_temp_max                float64
# Seville_temp_min               float64
# Madrid_temp                    float64
# Madrid_temp_min                float64
# load_shortfall_3h              float64
# year                             int32
# month                            int32
# day                              int32
# hour                             int32
# dtype: object

# %%
#dropping the 'time' and 'Unnamed: 0' columns
df_clean = df_clean.drop(['time','Unnamed: 0'], axis=1)
df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 11683 entries, 0 to 2919
# Data columns (total 50 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Madrid_wind_speed     11683 non-null  float64
#  1   Valencia_wind_deg     11683 non-null  int32
#  2   Bilbao_rain_1h        11683 non-null  float64
#  3   Valencia_wind_speed   11683 non-null  float64
#  4   Seville_humidity      11683 non-null  float64
#  5   Madrid_humidity       11683 non-null  float64
#  6   Bilbao_clouds_all     11683 non-null  float64
#  7   Bilbao_wind_speed     11683 non-null  float64
#  8   Seville_clouds_all    11683 non-null  float64
#  9   Bilbao_wind_deg       11683 non-null  float64
#  10  Barcelona_wind_speed  11683 non-null  float64
#  11  Barcelona_wind_deg    11683 non-null  float64
#  12  Madrid_clouds_all     11683 non-null  float64
#  13  Seville_wind_speed    11683 non-null  float64
#  14  Barcelona_rain_1h     11683 non-null  float64
#  15  Seville_pressure      11683 non-null  int32
#  16  Seville_rain_1h       11683 non-null  float64
#  17  Bilbao_snow_3h        11683 non-null  float64
#  18  Barcelona_pressure    11683 non-null  float64
#  19  Seville_rain_3h       11683 non-null  float64
#  20  Madrid_rain_1h        11683 non-null  float64
#  21  Barcelona_rain_3h     11683 non-null  float64
#  22  Valencia_snow_3h      11683 non-null  float64
#  23  Madrid_weather_id     11683 non-null  float64
#  24  Barcelona_weather_id  11683 non-null  float64
#  25  Bilbao_pressure       11683 non-null  float64
#  26  Seville_weather_id    11683 non-null  float64
#  27  Seville_temp_max      11683 non-null  float64
#  28  Madrid_pressure       11683 non-null  float64
#  29  Valencia_temp_max     11683 non-null  float64
#  30  Valencia_temp         11683 non-null  float64
#  31  Bilbao_weather_id     11683 non-null  float64
#  32  Seville_temp          11683 non-null  float64
#  33  Valencia_humidity     11683 non-null  float64
#  34  Valencia_temp_min     11683 non-null  float64
#  35  Barcelona_temp_max    11683 non-null  float64
#  36  Madrid_temp_max       11683 non-null  float64
#  37  Barcelona_temp        11683 non-null  float64
#  38  Bilbao_temp_min       11683 non-null  float64
#  39  Bilbao_temp           11683 non-null  float64
#  40  Barcelona_temp_min    11683 non-null  float64
#  41  Bilbao_temp_max       11683 non-null  float64
#  42  Seville_temp_min      11683 non-null  float64
#  43  Madrid_temp           11683 non-null  float64
#  44  Madrid_temp_min       11683 non-null  float64
#  45  load_shortfall_3h     8763 non-null   float64
#  46  year                  11683 non-null  int32
#  47  month                 11683 non-null  int32
#  48  day                   11683 non-null  int32
#  49  hour                  11683 non-null  int32
# dtypes: float64(44), int32(6)
# memory usage: 4.3 MB

# %%
# Creating a correlation matrix
corr = df_clean.corr()

# Finding rows and columns where correlation coefficients > 0.9 or <-0.9
corr[np.abs(corr) > 0.9]
# Out:
#                       Madrid_wind_speed  Valencia_wind_deg  Bilbao_rain_1h  \
# Madrid_wind_speed                   1.0                NaN             NaN
# Valencia_wind_deg                   NaN                1.0             NaN
# Bilbao_rain_1h                      NaN                NaN             1.0
# Valencia_wind_speed                 NaN                NaN             NaN
# Seville_humidity                    NaN                NaN             NaN
# Madrid_humidity                     NaN                NaN             NaN
# Bilbao_clouds_all                   NaN                NaN             NaN
# Bilbao_wind_speed                   NaN                NaN             NaN
# Seville_clouds_all                  NaN                NaN             NaN
# Bilbao_wind_deg                     NaN                NaN             NaN
# Barcelona_wind_speed                NaN                NaN             NaN
# Barcelona_wind_deg                  NaN                NaN             NaN
# Madrid_clouds_all                   NaN                NaN             NaN
# Seville_wind_speed                  NaN                NaN             NaN
# Barcelona_rain_1h                   NaN                NaN             NaN
# Seville_pressure                    NaN                NaN             NaN
# Seville_rain_1h                     NaN                NaN             NaN
# Bilbao_snow_3h                      NaN                NaN             NaN
# Barcelona_pressure                  NaN                NaN             NaN
# Seville_rain_3h                     NaN                NaN             NaN
# Madrid_rain_1h                      NaN                NaN             NaN
# Barcelona_rain_3h                   NaN                NaN             NaN
# Valencia_snow_3h                    NaN                NaN             NaN
# Madrid_weather_id                   NaN                NaN             NaN
# Barcelona_weather_id                NaN                NaN             NaN
# Bilbao_pressure                     NaN                NaN             NaN
# Seville_weather_id                  NaN                NaN             NaN
# Seville_temp_max                    NaN                NaN             NaN
# Madrid_pressure                     NaN                NaN             NaN
# Valencia_temp_max                   NaN                NaN             NaN
# Valencia_temp                       NaN                NaN             NaN
# Bilbao_weather_id                   NaN                NaN             NaN
# Seville_temp                        NaN                NaN             NaN
# Valencia_humidity                   NaN                NaN             NaN
# Valencia_temp_min                   NaN                NaN             NaN
# Barcelona_temp_max                  NaN                NaN             NaN
# Madrid_temp_max                     NaN                NaN             NaN
# Barcelona_temp                      NaN                NaN             NaN
# Bilbao_temp_min                     NaN                NaN             NaN
# Bilbao_temp                         NaN                NaN             NaN
# Barcelona_temp_min                  NaN                NaN             NaN
# Bilbao_temp_max                     NaN                NaN             NaN
# Seville_temp_min                    NaN                NaN             NaN
# Madrid_temp                         NaN                NaN             NaN
# Madrid_temp_min                     NaN                NaN             NaN
# load_shortfall_3h                   NaN                NaN             NaN
# year                                NaN                NaN             NaN
# month                               NaN                NaN             NaN
# day                                 NaN                NaN             NaN
# hour                                NaN                NaN             NaN
#
#                       Valencia_wind_speed  Seville_humidity  Madrid_humidity  \
# Madrid_wind_speed                     NaN               NaN              NaN
# Valencia_wind_deg                     NaN               NaN              NaN
# Bilbao_rain_1h                        NaN               NaN              NaN
# Valencia_wind_speed                   1.0               NaN              NaN
# Seville_humidity                      NaN               1.0              NaN
# Madrid_humidity                       NaN               NaN              1.0
# Bilbao_clouds_all                     NaN               NaN              NaN
# Bilbao_wind_speed                     NaN               NaN              NaN
# Seville_clouds_all                    NaN               NaN              NaN
# Bilbao_wind_deg                       NaN               NaN              NaN
# Barcelona_wind_speed                  NaN               NaN              NaN
# Barcelona_wind_deg                    NaN               NaN              NaN
# Madrid_clouds_all                     NaN               NaN              NaN
# Seville_wind_speed                    NaN               NaN              NaN
# Barcelona_rain_1h                     NaN               NaN              NaN
# Seville_pressure                      NaN               NaN              NaN
# Seville_rain_1h                       NaN               NaN              NaN
# Bilbao_snow_3h                        NaN               NaN              NaN
# Barcelona_pressure                    NaN               NaN              NaN
# Seville_rain_3h                       NaN               NaN              NaN
# Madrid_rain_1h                        NaN               NaN              NaN
# Barcelona_rain_3h                     NaN               NaN              NaN
# Valencia_snow_3h                      NaN               NaN              NaN
# Madrid_weather_id                     NaN               NaN              NaN
# Barcelona_weather_id                  NaN               NaN              NaN
# Bilbao_pressure                       NaN               NaN              NaN
# Seville_weather_id                    NaN               NaN              NaN
# Seville_temp_max                      NaN               NaN              NaN
# Madrid_pressure                       NaN               NaN              NaN
# Valencia_temp_max                     NaN               NaN              NaN
# Valencia_temp                         NaN               NaN              NaN
# Bilbao_weather_id                     NaN               NaN              NaN
# Seville_temp                          NaN               NaN              NaN
# Valencia_humidity                     NaN               NaN              NaN
# Valencia_temp_min                     NaN               NaN              NaN
# Barcelona_temp_max                    NaN               NaN              NaN
# Madrid_temp_max                       NaN               NaN              NaN
# Barcelona_temp                        NaN               NaN              NaN
# Bilbao_temp_min                       NaN               NaN              NaN
# Bilbao_temp                           NaN               NaN              NaN
# Barcelona_temp_min                    NaN               NaN              NaN
# Bilbao_temp_max                       NaN               NaN              NaN
# Seville_temp_min                      NaN               NaN              NaN
# Madrid_temp                           NaN               NaN              NaN
# Madrid_temp_min                       NaN               NaN              NaN
# load_shortfall_3h                     NaN               NaN              NaN
# year                                  NaN               NaN              NaN
# month                                 NaN               NaN              NaN
# day                                   NaN               NaN              NaN
# hour                                  NaN               NaN              NaN
#
#                       Bilbao_clouds_all  Bilbao_wind_speed  \
# Madrid_wind_speed                   NaN                NaN
# Valencia_wind_deg                   NaN                NaN
# Bilbao_rain_1h                      NaN                NaN
# Valencia_wind_speed                 NaN                NaN
# Seville_humidity                    NaN                NaN
# Madrid_humidity                     NaN                NaN
# Bilbao_clouds_all                   1.0                NaN
# Bilbao_wind_speed                   NaN                1.0
# Seville_clouds_all                  NaN                NaN
# Bilbao_wind_deg                     NaN                NaN
# Barcelona_wind_speed                NaN                NaN
# Barcelona_wind_deg                  NaN                NaN
# Madrid_clouds_all                   NaN                NaN
# Seville_wind_speed                  NaN                NaN
# Barcelona_rain_1h                   NaN                NaN
# Seville_pressure                    NaN                NaN
# Seville_rain_1h                     NaN                NaN
# Bilbao_snow_3h                      NaN                NaN
# Barcelona_pressure                  NaN                NaN
# Seville_rain_3h                     NaN                NaN
# Madrid_rain_1h                      NaN                NaN
# Barcelona_rain_3h                   NaN                NaN
# Valencia_snow_3h                    NaN                NaN
# Madrid_weather_id                   NaN                NaN
# Barcelona_weather_id                NaN                NaN
# Bilbao_pressure                     NaN                NaN
# Seville_weather_id                  NaN                NaN
# Seville_temp_max                    NaN                NaN
# Madrid_pressure                     NaN                NaN
# Valencia_temp_max                   NaN                NaN
# Valencia_temp                       NaN                NaN
# Bilbao_weather_id                   NaN                NaN
# Seville_temp                        NaN                NaN
# Valencia_humidity                   NaN                NaN
# Valencia_temp_min                   NaN                NaN
# Barcelona_temp_max                  NaN                NaN
# Madrid_temp_max                     NaN                NaN
# Barcelona_temp                      NaN                NaN
# Bilbao_temp_min                     NaN                NaN
# Bilbao_temp                         NaN                NaN
# Barcelona_temp_min                  NaN                NaN
# Bilbao_temp_max                     NaN                NaN
# Seville_temp_min                    NaN                NaN
# Madrid_temp                         NaN                NaN
# Madrid_temp_min                     NaN                NaN
# load_shortfall_3h                   NaN                NaN
# year                                NaN                NaN
# month                               NaN                NaN
# day                                 NaN                NaN
# hour                                NaN                NaN
#
#                       Seville_clouds_all  Bilbao_wind_deg  ...  \
# Madrid_wind_speed                    NaN              NaN  ...
# Valencia_wind_deg                    NaN              NaN  ...
# Bilbao_rain_1h                       NaN              NaN  ...
# Valencia_wind_speed                  NaN              NaN  ...
# Seville_humidity                     NaN              NaN  ...
# Madrid_humidity                      NaN              NaN  ...
# Bilbao_clouds_all                    NaN              NaN  ...
# Bilbao_wind_speed                    NaN              NaN  ...
# Seville_clouds_all                   1.0              NaN  ...
# Bilbao_wind_deg                      NaN              1.0  ...
# Barcelona_wind_speed                 NaN              NaN  ...
# Barcelona_wind_deg                   NaN              NaN  ...
# Madrid_clouds_all                    NaN              NaN  ...
# Seville_wind_speed                   NaN              NaN  ...
# Barcelona_rain_1h                    NaN              NaN  ...
# Seville_pressure                     NaN              NaN  ...
# Seville_rain_1h                      NaN              NaN  ...
# Bilbao_snow_3h                       NaN              NaN  ...
# Barcelona_pressure                   NaN              NaN  ...
# Seville_rain_3h                      NaN              NaN  ...
# Madrid_rain_1h                       NaN              NaN  ...
# Barcelona_rain_3h                    NaN              NaN  ...
# Valencia_snow_3h                     NaN              NaN  ...
# Madrid_weather_id                    NaN              NaN  ...
# Barcelona_weather_id                 NaN              NaN  ...
# Bilbao_pressure                      NaN              NaN  ...
# Seville_weather_id                   NaN              NaN  ...
# Seville_temp_max                     NaN              NaN  ...
# Madrid_pressure                      NaN              NaN  ...
# Valencia_temp_max                    NaN              NaN  ...
# Valencia_temp                        NaN              NaN  ...
# Bilbao_weather_id                    NaN              NaN  ...
# Seville_temp                         NaN              NaN  ...
# Valencia_humidity                    NaN              NaN  ...
# Valencia_temp_min                    NaN              NaN  ...
# Barcelona_temp_max                   NaN              NaN  ...
# Madrid_temp_max                      NaN              NaN  ...
# Barcelona_temp                       NaN              NaN  ...
# Bilbao_temp_min                      NaN              NaN  ...
# Bilbao_temp                          NaN              NaN  ...
# Barcelona_temp_min                   NaN              NaN  ...
# Bilbao_temp_max                      NaN              NaN  ...
# Seville_temp_min                     NaN              NaN  ...
# Madrid_temp                          NaN              NaN  ...
# Madrid_temp_min                      NaN              NaN  ...
# load_shortfall_3h                    NaN              NaN  ...
# year                                 NaN              NaN  ...
# month                                NaN              NaN  ...
# day                                  NaN              NaN  ...
# hour                                 NaN              NaN  ...
#
#                       Barcelona_temp_min  Bilbao_temp_max  Seville_temp_min  \
# Madrid_wind_speed                    NaN              NaN               NaN
# Valencia_wind_deg                    NaN              NaN               NaN
# Bilbao_rain_1h                       NaN              NaN               NaN
# Valencia_wind_speed                  NaN              NaN               NaN
# Seville_humidity                     NaN              NaN               NaN
# Madrid_humidity                      NaN              NaN               NaN
# Bilbao_clouds_all                    NaN              NaN               NaN
# Bilbao_wind_speed                    NaN              NaN               NaN
# Seville_clouds_all                   NaN              NaN               NaN
# Bilbao_wind_deg                      NaN              NaN               NaN
# Barcelona_wind_speed                 NaN              NaN               NaN
# Barcelona_wind_deg                   NaN              NaN               NaN
# Madrid_clouds_all                    NaN              NaN               NaN
# Seville_wind_speed                   NaN              NaN               NaN
# Barcelona_rain_1h                    NaN              NaN               NaN
# Seville_pressure                     NaN              NaN               NaN
# Seville_rain_1h                      NaN              NaN               NaN
# Bilbao_snow_3h                       NaN              NaN               NaN
# Barcelona_pressure                   NaN              NaN               NaN
# Seville_rain_3h                      NaN              NaN               NaN
# Madrid_rain_1h                       NaN              NaN               NaN
# Barcelona_rain_3h                    NaN              NaN               NaN
# Valencia_snow_3h                     NaN              NaN               NaN
# Madrid_weather_id                    NaN              NaN               NaN
# Barcelona_weather_id                 NaN              NaN               NaN
# Bilbao_pressure                      NaN              NaN               NaN
# Seville_weather_id                   NaN              NaN               NaN
# Seville_temp_max                     NaN              NaN               NaN
# Madrid_pressure                      NaN              NaN               NaN
# Valencia_temp_max                    NaN              NaN               NaN
# Valencia_temp                        NaN              NaN               NaN
# Bilbao_weather_id                    NaN              NaN               NaN
# Seville_temp                         NaN              NaN          0.961565
# Valencia_humidity                    NaN              NaN               NaN
# Valencia_temp_min                    NaN              NaN               NaN
# Barcelona_temp_max              0.908641              NaN               NaN
# Madrid_temp_max                      NaN              NaN          0.925381
# Barcelona_temp                  0.972538              NaN               NaN
# Bilbao_temp_min                      NaN         0.936350               NaN
# Bilbao_temp                          NaN         0.981878               NaN
# Barcelona_temp_min              1.000000              NaN               NaN
# Bilbao_temp_max                      NaN         1.000000               NaN
# Seville_temp_min                     NaN              NaN          1.000000
# Madrid_temp                          NaN              NaN          0.937541
# Madrid_temp_min                      NaN              NaN          0.911220
# load_shortfall_3h                    NaN              NaN               NaN
# year                                 NaN              NaN               NaN
# month                                NaN              NaN               NaN
# day                                  NaN              NaN               NaN
# hour                                 NaN              NaN               NaN
#
#                       Madrid_temp  Madrid_temp_min  load_shortfall_3h  year  \
# Madrid_wind_speed             NaN              NaN                NaN   NaN
# Valencia_wind_deg             NaN              NaN                NaN   NaN
# Bilbao_rain_1h                NaN              NaN                NaN   NaN
# Valencia_wind_speed           NaN              NaN                NaN   NaN
# Seville_humidity              NaN              NaN                NaN   NaN
# Madrid_humidity               NaN              NaN                NaN   NaN
# Bilbao_clouds_all             NaN              NaN                NaN   NaN
# Bilbao_wind_speed             NaN              NaN                NaN   NaN
# Seville_clouds_all            NaN              NaN                NaN   NaN
# Bilbao_wind_deg               NaN              NaN                NaN   NaN
# Barcelona_wind_speed          NaN              NaN                NaN   NaN
# Barcelona_wind_deg            NaN              NaN                NaN   NaN
# Madrid_clouds_all             NaN              NaN                NaN   NaN
# Seville_wind_speed            NaN              NaN                NaN   NaN
# Barcelona_rain_1h             NaN              NaN                NaN   NaN
# Seville_pressure              NaN              NaN                NaN   NaN
# Seville_rain_1h               NaN              NaN                NaN   NaN
# Bilbao_snow_3h                NaN              NaN                NaN   NaN
# Barcelona_pressure            NaN              NaN                NaN   NaN
# Seville_rain_3h               NaN              NaN                NaN   NaN
# Madrid_rain_1h                NaN              NaN                NaN   NaN
# Barcelona_rain_3h             NaN              NaN                NaN   NaN
# Valencia_snow_3h              NaN              NaN                NaN   NaN
# Madrid_weather_id             NaN              NaN                NaN   NaN
# Barcelona_weather_id          NaN              NaN                NaN   NaN
# Bilbao_pressure               NaN              NaN                NaN   NaN
# Seville_weather_id            NaN              NaN                NaN   NaN
# Seville_temp_max              NaN              NaN                NaN   NaN
# Madrid_pressure               NaN              NaN                NaN   NaN
# Valencia_temp_max        0.915525              NaN                NaN   NaN
# Valencia_temp            0.917144              NaN                NaN   NaN
# Bilbao_weather_id             NaN              NaN                NaN   NaN
# Seville_temp             0.912556              NaN                NaN   NaN
# Valencia_humidity             NaN              NaN                NaN   NaN
# Valencia_temp_min             NaN              NaN                NaN   NaN
# Barcelona_temp_max       0.904874              NaN                NaN   NaN
# Madrid_temp_max          0.990703         0.950082                NaN   NaN
# Barcelona_temp           0.908504              NaN                NaN   NaN
# Bilbao_temp_min               NaN              NaN                NaN   NaN
# Bilbao_temp                   NaN              NaN                NaN   NaN
# Barcelona_temp_min            NaN              NaN                NaN   NaN
# Bilbao_temp_max               NaN              NaN                NaN   NaN
# Seville_temp_min         0.937541         0.911220                NaN   NaN
# Madrid_temp              1.000000         0.978677                NaN   NaN
# Madrid_temp_min          0.978677         1.000000                NaN   NaN
# load_shortfall_3h             NaN              NaN                1.0   NaN
# year                          NaN              NaN                NaN   1.0
# month                         NaN              NaN                NaN   NaN
# day                           NaN              NaN                NaN   NaN
# hour                          NaN              NaN                NaN   NaN
#
#                       month  day  hour
# Madrid_wind_speed       NaN  NaN   NaN
# Valencia_wind_deg       NaN  NaN   NaN
# Bilbao_rain_1h          NaN  NaN   NaN
# Valencia_wind_speed     NaN  NaN   NaN
# Seville_humidity        NaN  NaN   NaN
# Madrid_humidity         NaN  NaN   NaN
# Bilbao_clouds_all       NaN  NaN   NaN
# Bilbao_wind_speed       NaN  NaN   NaN
# Seville_clouds_all      NaN  NaN   NaN
# Bilbao_wind_deg         NaN  NaN   NaN
# Barcelona_wind_speed    NaN  NaN   NaN
# Barcelona_wind_deg      NaN  NaN   NaN
# Madrid_clouds_all       NaN  NaN   NaN
# Seville_wind_speed      NaN  NaN   NaN
# Barcelona_rain_1h       NaN  NaN   NaN
# Seville_pressure        NaN  NaN   NaN
# Seville_rain_1h         NaN  NaN   NaN
# Bilbao_snow_3h          NaN  NaN   NaN
# Barcelona_pressure      NaN  NaN   NaN
# Seville_rain_3h         NaN  NaN   NaN
# Madrid_rain_1h          NaN  NaN   NaN
# Barcelona_rain_3h       NaN  NaN   NaN
# Valencia_snow_3h        NaN  NaN   NaN
# Madrid_weather_id       NaN  NaN   NaN
# Barcelona_weather_id    NaN  NaN   NaN
# Bilbao_pressure         NaN  NaN   NaN
# Seville_weather_id      NaN  NaN   NaN
# Seville_temp_max        NaN  NaN   NaN
# Madrid_pressure         NaN  NaN   NaN
# Valencia_temp_max       NaN  NaN   NaN
# Valencia_temp           NaN  NaN   NaN
# Bilbao_weather_id       NaN  NaN   NaN
# Seville_temp            NaN  NaN   NaN
# Valencia_humidity       NaN  NaN   NaN
# Valencia_temp_min       NaN  NaN   NaN
# Barcelona_temp_max      NaN  NaN   NaN
# Madrid_temp_max         NaN  NaN   NaN
# Barcelona_temp          NaN  NaN   NaN
# Bilbao_temp_min         NaN  NaN   NaN
# Bilbao_temp             NaN  NaN   NaN
# Barcelona_temp_min      NaN  NaN   NaN
# Bilbao_temp_max         NaN  NaN   NaN
# Seville_temp_min        NaN  NaN   NaN
# Madrid_temp             NaN  NaN   NaN
# Madrid_temp_min         NaN  NaN   NaN
# load_shortfall_3h       NaN  NaN   NaN
# year                    NaN  NaN   NaN
# month                   1.0  NaN   NaN
# day                     NaN  1.0   NaN
# hour                    NaN  NaN   1.0
#
# [50 rows x 50 columns]

# %% [markdown]
# <a id="five"></a>
# ## 5. Modelling
# <a class="anchor" id="1.1"></a>
# <a href=#cont>Back to Table of Contents</a>
#
# ---
#
# | ⚡ Description: Modelling ⚡ |
# | :--------------------------- |
# | In this section, you are required to create one or more regression models that are able to accurately predict the thee hour load shortfall. |
#
# ---

# %%
'''
# split data
x = df_clean[:len(df_train)].drop('load_shortfall_3h', axis=1)
y = df_clean[:len(df_train)][['load_shortfall_3h']]
print('shape of orignal training dataset:', df_train.shape)
print('shape of x:', x.shape)
print('shape of y:', y.shape)

'''
# Out:
# "\n# split data\nx = df_clean[:len(df_train)].drop('load_shortfall_3h', axis=1)\ny = df_clean[:len(df_train)][['load_shortfall_3h']]\nprint('shape of orignal training dataset:', df_train.shape)\nprint('shape of x:', x.shape)\nprint('shape of y:', y.shape)\n\n"

# %%
from sklearn.model_selection import train_test_split

# %%
# create targets and features dataset

# %%
# create one or more ML models

# %%
# evaluate one or more ML models

# %% [markdown]
# <a id="six"></a>
# ## 6. Model Performance
# <a class="anchor" id="1.1"></a>
# <a href=#cont>Back to Table of Contents</a>
#
# ---
#
# | ⚡ Description: Model performance ⚡ |
# | :--------------------------- |
# | In this section you are required to compare the relative performance of the various trained ML models on a holdout dataset and comment on what model is the best and why. |
#
# ---

# %%
# Compare model performance

# %%
# Choose best model and motivate why it is the best choice

# %% [markdown]
# <a id="seven"></a>
# ## 7. Model Explanations
# <a class="anchor" id="1.1"></a>
# <a href=#cont>Back to Table of Contents</a>
#
# ---
#
# | ⚡ Description: Model explanation ⚡ |
# | :--------------------------- |
# | In this section, you are required to discuss how the best performing model works in a simple way so that both technical and non-technical stakeholders can grasp the intuition behind the model's inner workings. |
#
# ---

# %%
# discuss chosen methods logic
